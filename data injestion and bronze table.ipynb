# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/customer_data/")

# %%
# %fs head dbfs:/FileStore/tables/customer_data/ecommerce_customer_churn_dataset.csv

# %%
df= spark.read.csv("dbfs:/FileStore/tables/customer_data/ecommerce_customer_churn_dataset.csv", header=True, inferSchema=True)
df.show(5)

# %%
from pyspark.sql.functions import monotonically_increasing_id
from pyspark.sql.functions import count, when, col

# 1. Read CSV (replace with your actual path)
df = spark.read.csv("/FileStore/tables/customer_data/ecommerce_customer_churn_dataset.csv", header=True, inferSchema=True)

# 2. Add customer_id using monotonically_increasing_id
df1 = df.withColumn("customer_id", monotonically_increasing_id()+1)

# 3. Check schema
df1.printSchema()

# 4. Count records
print(f"Total records: {df1.count()}")

# 5. Display first 5 rows
df1.show(5)

# 6. Check for null values
df1.select([count(when(col(c).isNull(), c)).alias(c) for c in df1.columns]).show()

# %%
df1.show(5)

# %%
df1.createOrReplaceTempView("bronze_customer_data")
print("table created successfully")

# %%
# %sql
select * from bronze_customer_data

# %%
dbutils.fs.rm("dbfs:/user", recurse=True)

# %%
dbutils.fs.rm("dbfs:/mnt/your_subdirectory", recurse=True)

# %%
dbutils.fs.rm("/mnt/your_directory", recurse=True)
